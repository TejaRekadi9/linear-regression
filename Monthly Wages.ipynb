# %% [markdown]
# ## Monthly Wages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataset=pd.read_csv('Monthly Wages.csv')

# %%
dataset
# Out:
#      S.No  Study  Travelling  Shopping  Daily Wages
# 0       1   4268        2212      4868         1802
# 1       2   4301        2357      3106         3012
# 2       3   3231        2149      4087         3071
# 3       4   4340        2293      1212         3107
# 4       5   4542        2385      4510         2422
# ..    ...    ...         ...       ...          ...
# 195   196   5501        2370      3776         3253
# 196   197   5326        2884      3072         1562
# 197   198   4163        2127      1135         1176
# 198   199   3586        2312      4828         3522
# 199   200   3300        2502      3065         1152
#
# [200 rows x 5 columns]

# %% [markdown]
# ## Linear Regression

# %%
x=dataset['Study'].values.reshape(-1,1)
y=dataset['Travelling'].values.reshape(-1,1)

# %%
plt.figure(figsize=(15,7))
plt.scatter(x,y,c='black')
plt.xlabel("Study")
plt.ylabel("Travelling")
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y, test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)
plt.figure(figsize=(16,8))
plt.scatter(x,y, c='black')
plt.plot(
    x_test,
    y_pred,
    c='red',
    linewidth=3
)
plt.xlabel("Study")
plt.ylabel("Travelling")
plt.show()

# %%
reg.coef_
# Out:
# array([[0.07316401]])

# %%
reg.intercept_
# Out:
# array([2158.07785369])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# -0.09094821956269583

# %%
output=reg.predict([[276.12]])
output
# Out:
# array([[2178.27989906]])

# %% [markdown]
# ## Multiple Linear Regression

# %%
x=dataset.drop(['Study'],axis=1)
y=dataset['Travelling'].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y, test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
multiple_reg=LinearRegression()
multiple_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = multiple_reg.predict(x_test)

# %%
multiple_reg.intercept_
# Out:
# array([-4.54747351e-13])

# %%
multiple_reg.coef_
# Out:
# array([[ 1.17213624e-16,  1.00000000e+00, -4.80696560e-17,
#          1.88825395e-16]])

# %% [markdown]
# ## Evaluating the matrices

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_test,y_pred))
# Out:
# 1.0610771520684163e-13

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)
r2
# Out:
# 1.0
